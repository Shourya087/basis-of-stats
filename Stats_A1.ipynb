# %% [markdown]
# #Basic of Statistics

# %% [markdown]
# 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales
# --types of data
# A. qualitative in this there are
# nominal(unordered, non- numercic eg. gender, blood group)
# ordinal(ordered, non-numeric eg. rank, grade) types of data \
# B. quantitative in this there are
# discrete(numeric with whole number values eg. number of children in a bus)
# continuous(numeric with non whole number values eg. height, weight) types of data
# scaling of data
# A. nominal- non-numeric, non-ordered data
# B. ordinal- non-numeric, ordered data
# C. interval- numeric, non-zero starting point
# D. ratio- numeric, zero starting point

# %% [markdown]
# 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median, and mode with examples and situations where each is appropriate.
# --measures of central tendencies are a way to compile the data
# uses of each
# A. mean- for numeric data if outliner is not present eg when data is (1,2,3,4,5,6,7)
# B. median- for numeric data if outliner is present eg when data is (1,2,3,4,5,1000)
# C. mode- for both numeric and non-numeric data eg when data is (1,2,2,2,3,3,4,5,6,6)

# %% [markdown]
# 3.  Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
# --concept of dispersion is how the data is spread out
# variance is the summation of squared of difference in each value and mean through calculation we can measue the spread of data
# standard deviation is square root of variance and helps in finding spread of data

# %% [markdown]
# 4. What is a box plot, and what can it tell you about the distribution of data
# --box plot is the plot which is made with help of quartiles, IQR to check the values in data and it can also help to check presence of outliner

# %% [markdown]
# 5. Discuss the role of random sampling in making inferences about populations
# --it is a type of sampling where every individual has equal chance of being selected it helps in making a sample of a large population for statistical purposes

# %% [markdown]
# 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
# --skewness is the measure of data distribution in statistics and it helps in making comparison among mean, median, mode values of same data
# 2 types of skewness are positive and negative
# positive- right handed skewness meaning data is distributed more to right side of graph (mean>= median >= mode)
# negative- left handed skewness meaning data is distributed more to left side of graph (mode>= median >= mean)

# %% [markdown]
# 7. What is the interquartile range (IQR), and how is it used to detect outliers?
# --IQR is the difference between Q3 and Q1 values
# it helps in calculating lower fence(Q1 - IQR * 1.5) And upper fence(Q3 + IQR* 1.5) and if any value lie beyond those it is considered as a outliner

# %% [markdown]
# 8. Discuss the conditions under which the binomial distribution is used

# %% [markdown]
# 9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule)

# %% [markdown]
# 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
# --to calculate proability of specific event we take totalm outcomes nad possible outcome in consideration for example in coin toss total outcomes are 2(heads or tails) and probability to get heads is 1 same way 1 as of tails so probability is favourable outcomes divided by total number of outcomes

# %% [markdown]
# 11. Explain what a random variable is and differentiate between discrete and continuous random variables
# --random variable is a set of possible values from an experiment
# discerte random varibles are whole numbers
# continuous random variables are ranged values

# %% [markdown]
# 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.

# %%
import seaborn as sns

# %%
table = sns.load_dataset("tips")

# %%
table
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
table.cov(numeric_only= True)
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
table.corr(numeric_only= True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
